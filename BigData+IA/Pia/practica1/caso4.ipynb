# %% [markdown]
# Vamos a usar un cuaderno de Jupyter que mediante ! puede ejecutar comandos del sistema:

# %%
jugadas = !../ppt #en Jupyter Notebooks con ! se ejecuta algo en el sistema
jugadas #jugadas es una lista
# Out:
# ['Tijera',
#  'Tijera',
#  'Tijera',
#  'Tijera',
#  'Tijera',
#  'Piedra',
#  'Tijera',
#  'Tijera',
#  'Tijera',
#  'Tijera',
#  'Papel',
#  'Piedra',
#  'Piedra',
#  'Tijera',
#  'Papel',
#  'Tijera',
#  'Piedra',
#  'Papel',
#  'Piedra',
#  'Piedra',
#  'Piedra',
#  'Papel',
#  'Piedra',
#  'Papel',
#  'Papel',
#  'Piedra',
#  'Papel',
#  'Tijera',
#  'Piedra',
#  'Papel',
#  'Piedra',
#  'Piedra',
#  'Papel',
#  'Piedra',
#  'Papel',
#  'Tijera',
#  'Tijera',
#  'Papel',
#  'Piedra',
#  'Piedra',
#  'Piedra',
#  'Piedra',
#  'Piedra',
#  'Piedra',
#  'Papel',
#  'Tijera',
#  'Piedra',
#  'Tijera',
#  'Piedra',
#  'Piedra',
#  'Papel',
#  'Tijera',
#  'Papel',
#  'Piedra',
#  'Tijera',
#  'Papel',
#  'Tijera',
#  'Tijera',
#  'Piedra',
#  'Tijera',
#  'Piedra',
#  'Piedra',
#  'Tijera',
#  'Piedra',
#  'Piedra',
#  'Tijera',
#  'Tijera',
#  'Papel',
#  'Papel',
#  'Papel',
#  'Piedra',
#  'Tijera',
#  'Piedra',
#  'Tijera',
#  'Piedra',
#  'Papel',
#  'Papel',
#  'Piedra',
# ...
